# %%
import mutual as M
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# def plot_MI(path=testPath, refImg='image-01.jpeg', k=25):

# %%
print("1 sat ref for all Google (street imgs)")
M.plot_MI("University-Release/train/google/0839", "University-Release/train/drone/0839/image-01.jpeg", 25)

print("1 sat ref for all drone")
M.plot_MI("University-Release/train/drone/0839", "University-Release/train/satellite/0839/0839.jpg", 25)
# Out:
# 1 sat ref for all Google (street imgs)
# [0.03609963898448858, 0.03594445400424319, 0.033503838406619524, 0.030393161247538818, 0.02937416820060236, 0.02837972727263768, 0.02815100534181001, 0.02782645932587765, 0.02624863251912953, 0.026219336124637872, 0.024011484928397817, 0.019759013760149515, 0.01916756814227745, 0.01849173014541452, 0.018042536804825524, 0.015461398473804077, 0.012755758288622429]
# ...

# %%
print("1 sat ref for all Google (street imgs)")
M.plot_MI("University-Release/train/google/0842", "University-Release/train/drone/0842/image-01.jpeg", 25)

print("1 sat ref for all drone")
M.plot_MI("University-Release/train/drone/0842", "University-Release/train/satellite/0842/0842.jpg", 25)
# Out:
# 1 sat ref for all Google (street imgs)
# [0.029846313365920765, 0.024220419432295963, 0.023720817900836213, 0.023439508325269913, 0.023192910895222622, 0.02189870919225087, 0.021235023350085876, 0.02111110754677846, 0.0081898614727525]
# ['1.At_Manchester_2018_003.jpg', '7.godlee-observatory-dome.jpg', '3.16409_large.jpg', '15.847517648_8f58cd53d1_b.jpg', '2.godlee_large-1a.jpg', '6.godlee_dome_airshot.jpg', '19.DnhlNNqWsAASAuf.jpg', '24.original.jpg', '9.mc-5.jpg']
# 1 sat ref for all drone
# ...

# %%
print("1 sat ref for all Google (street imgs)")
M.plot_MI("University-Release/train/google/1000", "University-Release/train/drone/1000/image-01.jpeg", 25)

print("1 sat ref for all drone")
M.plot_MI("University-Release/train/drone/1000", "University-Release/train/satellite/1000/1000.jpg", 25)
# Out:
# 1 sat ref for all Google (street imgs)
# [0.05966463994149509, 0.059195224634100804, 0.05845094083714735, 0.05595893466973146, 0.053085957903799344, 0.05106079539051223, 0.0484174725125805, 0.04167365582491082, 0.039640497470740534]
# ['11.00612_N192_board-web.jpg', '25.picture-41.jpg', '10.dscn1577.jpg', '14.hedco_northeast.jpg', '9.161101_10_UO-CoE-759x506.jpg', '6.oregondigital-df67rk49n.jpg', '24.BbwdYvGVNsK4JOlJaCcn2JluG8XQmCq9epIX_iuE2ho.jpg', '18.dscn1575.jpg', '15.329380_2TcfVE8YETR_TJECfMaNjJQ9qI0V3TEwcLNZbneBdcQ.jpg']
# 1 sat ref for all drone
# ...
